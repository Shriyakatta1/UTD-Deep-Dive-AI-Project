# %%
import pandas as pd
data = pd.read_csv('Unemployment2023 (1).csv')
data_new = data[data['State'] == 'TX']
data_new
data_newest = data_new.copy()
data_newest
# Out:
#         FIPS_Code State          Area_Name  \
# 258923      48000    TX              Texas
# 258927      48000    TX              Texas
# 258931      48000    TX              Texas
# 258935      48000    TX              Texas
# 258939      48000    TX              Texas
# ...           ...   ...                ...
# 284661      48507    TX  Zavala County, TX
# 284665      48507    TX  Zavala County, TX
# 284669      48507    TX  Zavala County, TX
# 284671      48507    TX  Zavala County, TX
# 284672      48507    TX  Zavala County, TX
#
#                                         Attribute     Value
# 258923                            Unemployed_2000  455364.0
# 258927                            Unemployed_2001  524310.0
# 258931                            Unemployed_2002  680965.0
# 258935                            Unemployed_2003  734082.0
# 258939                            Unemployed_2004  662144.0
# ...                                           ...       ...
# ...

# %%
data_newest.drop(data_newest[data_newest['Area_Name'] == 'Texas'].index, inplace = True)
data_newest
# Out:
#         FIPS_Code State            Area_Name  \
# 259019      48001    TX  Anderson County, TX
# 259020      48001    TX  Anderson County, TX
# 259021      48001    TX  Anderson County, TX
# 259024      48001    TX  Anderson County, TX
# 259028      48001    TX  Anderson County, TX
# ...           ...   ...                  ...
# 284661      48507    TX    Zavala County, TX
# 284665      48507    TX    Zavala County, TX
# 284669      48507    TX    Zavala County, TX
# 284671      48507    TX    Zavala County, TX
# 284672      48507    TX    Zavala County, TX
#
#                                         Attribute    Value
# 259019            Rural_Urban_Continuum_Code_2023      7.0
# 259020                  Urban_Influence_Code_2013      8.0
# 259021                                 Metro_2023      0.0
# 259024                            Unemployed_2000   1210.0
# 259028                            Unemployed_2001   1188.0
# ...                                           ...      ...
# ...

# %%
irs_data = pd.read_csv('22incytx.xlsx - Sheet1.csv')
irs_data_newer = pd.DataFrame()
index = 12
for index, val in enumerate(irs_data['Size of adjusted gross income by county']):
    irs_data_newer = pd.concat([irs_data_newer, irs_data.iloc[index]])         
    index += 8

irs_data_newer
# Out:
#                                            0    1    2    3    4    5    6     \
# County \nFIPS \ncode [1]                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Size of adjusted gross income by county     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 2                               Amount  NaN  NaN  NaN  NaN  NaN  NaN
# County \nFIPS \ncode [1]                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Size of adjusted gross income by county     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                         ...  ...  ...  ...  ...  ...  ...
# Size of adjusted gross income by county     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 2                                  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# County \nFIPS \ncode [1]                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Size of adjusted gross income by county     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 2                                  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ...
