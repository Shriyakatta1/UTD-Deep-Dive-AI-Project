# %%
#pip install numpy pandas matplotlib seaborn scikit-learn openpyxl beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\DGcoo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#     --------------------------------------- 1.3/69.5 MB 7.7 MB/s eta 0:00:09
#    - -------------------------------------- 3.4/69.5 MB 8.5 MB/s eta 0:00:08
#    --- ------------------------------------ 5.5/69.5 MB 9.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 7.9/69.5 MB 9.5 MB/s eta 0:00:07
#    ------ --------------------------------- 10.7/69.5 MB 10.2 MB/s eta 0:00:06
#    ------- -------------------------------- 13.6/69.5 MB 10.9 MB/s eta 0:00:06
#    --------- ------------------------------ 16.8/69.5 MB 11.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 20.4/69.5 MB 12.1 MB/s eta 0:00:05
#    ------------- -------------------------- 23.3/69.5 MB 12.2 MB/s eta 0:00:04
#    --------------- ------------------------ 26.2/69.5 MB 12.3 MB/s eta 0:00:04
# ...

# %%
#pip install keras_tuner tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 2.6/351.2 MB 12.9 MB/s eta 0:00:27
#     --------------------------------------- 6.0/351.2 MB 14.4 MB/s eta 0:00:25
#    - -------------------------------------- 9.4/351.2 MB 14.9 MB/s eta 0:00:23
#    - -------------------------------------- 12.6/351.2 MB 15.1 MB/s eta 0:00:23
#    - -------------------------------------- 16.0/351.2 MB 15.1 MB/s eta 0:00:23
#    -- ------------------------------------- 19.7/351.2 MB 15.4 MB/s eta 0:00:22
#    -- ------------------------------------- 23.1/351.2 MB 15.5 MB/s eta 0:00:22
#    --- ------------------------------------ 26.7/351.2 MB 15.8 MB/s eta 0:00:21
#    --- ------------------------------------ 30.7/351.2 MB 16.0 MB/s eta 0:00:20
# ...

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
import pandas as pd
from xgboost import XGBRegressor, XGBClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
import keras_tuner as kt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 8
#       4 from xgboost import XGBRegressor, XGBClassifier
#       5 import matplotlib.pyplot as plt
#       6 from sklearn.metrics import accuracy_score, mean_absolute_error, r2_score
#       7 from sklearn.model_selection import GridSearchCV
# ----> 8 import tensorflow as tf
#       9 import keras_tuner as kt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
# ...

# %%
data = pd.read_csv('Combined_dataset_model.csv')
X = data.drop(['health_nor', 'temp_norm', 'biome', 'county'], axis = 1)
y1 = data['health_nor']
y2 = data['temp_norm']

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size = 0.2, random_state = 42)

# %%
param_grid = {
    'max_depth': [2, 3, 4, 5, 6],
    'learning_rate': [0.01, 0.05, 0.1, 0.5, 1]
}
grid_search = GridSearchCV(
    estimator = XGBRegressor(n_estimators = 100, enable_categorical = True, random_state=42),
    param_grid = param_grid,
    scoring='accuracy'
)
grid_search.fit(X_train, y1_train)
print("y1 parameters:", grid_search.best_params_)
print("y1 CV accuracy:", round(grid_search.best_score_, 4))
print("y1 test accuracy:", round(grid_search.best_estimator_.score(X_test, y1_test), 4))

grid_search.fit(X_train, y2_train)
print("y2 parameters:", grid_search.best_params_)
print("y2 CV accuracy:", round(grid_search.best_score_, 4))
print("y2 test accuracy:", round(grid_search.best_estimator_.score(X_test, y2_test), 4))
# Out:
# C:\Users\DGcoo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py:956: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\DGcoo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py", line 945, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "C:\Users\DGcoo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py", line 80, in inner_f
#     return f(*args, **kwargs)
# ...

# %%
xgb_model1 = XGBRegressor(n_estimators=100, max_depth=4, learning_rate=0.01, objective='reg:squarederror', enable_categorical = True)
xgb_model1.fit(X_train, y1_train)
xgb_pred1 = xgb_model1.predict(X_test)
print("R2 Score:", r2_score(y1_test, xgb_pred1))
print("MAE:", mean_absolute_error(y1_test, xgb_pred1))

xgb_model2 = XGBRegressor(n_estimators=100, max_depth=4, learning_rate=0.01, objective='reg:squarederror', enable_categorical = True)
xgb_model2.fit(X_train, y2_train)
xgb_pred2 = xgb_model2.predict(X_test)
print("R2 Score:", r2_score(y1_test, xgb_pred1))
print("MAE:", mean_absolute_error(y1_test, xgb_pred1))
# Out:
# R2 Score: 0.45893805620547945
# MAE: 0.09909731991516403
# R2 Score: 0.45893805620547945
# MAE: 0.09909731991516403
