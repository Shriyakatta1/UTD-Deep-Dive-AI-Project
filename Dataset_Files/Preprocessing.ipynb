# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Filtering all the AQI Databases from the last 5 years to only include Texas

# %%
# 2025
df = pd.read_csv("/content/annual_aqi_by_county_2025.csv")
texasAQI_25 = df[df["State"] == "Texas"]
print(texasAQI_25.shape)
texasAQI_25.head(10)
# Out:
# (45, 18)
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 798  Texas   Atascosa  2025            341        259             82
# 799  Texas       Bell  2025            365        241            120
# 800  Texas      Bexar  2025            365        158            196
# 801  Texas      Bowie  2025            342        188            153
# 802  Texas   Brazoria  2025            365        295             62
# 803  Texas     Brazos  2025            340        233            107
# 804  Texas   Brewster  2025            364        272             91
# 805  Texas    Cameron  2025            365        109            248
# 806  Texas     Collin  2025            359        272             64
# 807  Texas  Culberson  2025             88         67             19
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 798                                    0               0                    0
# ...

# %%
# 2024
df = pd.read_csv("/content/annual_aqi_by_county_2024.csv")
texasAQI_24 = df[df["State"] == "Texas"]
print(texasAQI_24.shape)
texasAQI_24.head(10)
# Out:
# (45, 18)
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 808  Texas   Atascosa  2024            347        198            141
# 809  Texas       Bell  2024            366        226            135
# 810  Texas      Bexar  2024            366        174            170
# 811  Texas      Bowie  2024            360        189            171
# 812  Texas   Brazoria  2024            365        303             56
# 813  Texas     Brazos  2024            353        232            120
# 814  Texas   Brewster  2024            327        231             94
# 815  Texas    Cameron  2024            366         99            206
# 816  Texas     Collin  2024            365        283             71
# 817  Texas  Culberson  2024            111         99             12
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 808                                    8               0                    0
# ...

# %%
# 2023
df = pd.read_csv("/content/annual_aqi_by_county_2023.csv")
texasAQI_23 = df[df["State"] == "Texas"]
print(texasAQI_23.shape)
texasAQI_23.head(10)
# Out:
# (45, 18)
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 806  Texas   Atascosa  2023            330        210            120
# 807  Texas       Bell  2023            365        231            128
# 808  Texas      Bexar  2023            365        164            189
# 809  Texas      Bowie  2023            321        130            190
# 810  Texas   Brazoria  2023            365        301             47
# 811  Texas     Brazos  2023            348        233            115
# 812  Texas   Brewster  2023            359        262             96
# 813  Texas    Cameron  2023            365        161            198
# 814  Texas     Collin  2023            356        261             74
# 815  Texas  Culberson  2023            107        101              6
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 806                                    0               0                    0
# ...

# %%
# 2022
df = pd.read_csv("/content/annual_aqi_by_county_2022.csv")
texasAQI_22 = df[df["State"] == "Texas"]
print(texasAQI_22.shape)
texasAQI_22.head(10)
# Out:
# (45, 18)
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 806  Texas   Atascosa  2023            330        210            120
# 807  Texas       Bell  2023            365        231            128
# 808  Texas      Bexar  2023            365        164            189
# 809  Texas      Bowie  2023            321        130            190
# 810  Texas   Brazoria  2023            365        301             47
# 811  Texas     Brazos  2023            348        233            115
# 812  Texas   Brewster  2023            359        262             96
# 813  Texas    Cameron  2023            365        161            198
# 814  Texas     Collin  2023            356        261             74
# 815  Texas  Culberson  2023            107        101              6
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 806                                    0               0                    0
# ...

# %%
# 2021
df = pd.read_csv("/content/annual_aqi_by_county_2021.csv")
texasAQI_21 = df[df["State"] == "Texas"]
print(texasAQI_21.shape)
texasAQI_21.head(10)
# Out:
# (45, 18)
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 806  Texas   Atascosa  2023            330        210            120
# 807  Texas       Bell  2023            365        231            128
# 808  Texas      Bexar  2023            365        164            189
# 809  Texas      Bowie  2023            321        130            190
# 810  Texas   Brazoria  2023            365        301             47
# 811  Texas     Brazos  2023            348        233            115
# 812  Texas   Brewster  2023            359        262             96
# 813  Texas    Cameron  2023            365        161            198
# 814  Texas     Collin  2023            356        261             74
# 815  Texas  Culberson  2023            107        101              6
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 806                                    0               0                    0
# ...

# %% [markdown]
# Combining seperate years of AQI data into one dataset with all 5 years

# %%
# code for combining aqi data
pd.concat([texas])

# %% [markdown]
# Filtering all the Temperature data from the last 5 years to only include Texas

# %%
Temperature = pd.read_csv("/content/avg_temp_2021_2025.csv", header=2, skiprows=[2])
Temperature.rename(columns={"Name": "County"}, inplace=True)
print(Temperature.shape)
Temperature.head(10)
# Out:
# (254, 7)
#        ID            County  State  Value  Anomaly (1901-2000 base period)  \
# 0  TX-001   Anderson County  Texas   67.2                              1.8
# 1  TX-003    Andrews County  Texas   64.9                              3.0
# 2  TX-005   Angelina County  Texas   68.5                              2.5
# 3  TX-007    Aransas County  Texas   73.7                              3.3
# 4  TX-009     Archer County  Texas   65.9                              2.4
# 5  TX-011  Armstrong County  Texas   61.1                              3.2
# 6  TX-013   Atascosa County  Texas   72.2                              2.4
# 7  TX-015     Austin County  Texas   71.6                              3.7
# 8  TX-017     Bailey County  Texas   59.7                              2.7
# 9  TX-019    Bandera County  Texas   68.8                              2.7
#
#    Rank  1901-2000 Mean
# 0   126            65.4
# 1   127            61.9
# 2   127            66.1
# 3   127            70.3
# ...

# %% [markdown]
# Filtering all the Rainfall data to only include Texas

# %%
Rainfall = pd.read_csv("/content/avg_rain_2021_2025.csv", header=2, skiprows=[2])
Rainfall.rename(columns={"Name": "County"}, inplace=True)
print(Rainfall.shape)
Rainfall.head(10)
# Out:
# (254, 9)
#        ID            County  State   Value  Anomaly (1901-2000 base period)  \
# 0  TX-001   Anderson County  Texas  227.33                            19.94
# 1  TX-003    Andrews County  Texas   48.52                           -25.36
# 2  TX-005   Angelina County  Texas  260.54                            17.89
# 3  TX-007    Aransas County  Texas  162.20                            -6.36
# 4  TX-009     Archer County  Texas  140.27                             1.49
# 5  TX-011  Armstrong County  Texas   99.13                            -5.58
# 6  TX-013   Atascosa County  Texas  107.48                           -25.78
# 7  TX-015     Austin County  Texas  193.85                           -11.61
# 8  TX-017     Bailey County  Texas   82.03                            -5.69
# 9  TX-019    Bandera County  Texas  113.39                           -35.99
#
#    Rank  1901-2000 Mean  Pctavg  Percent of Average
# 0   106          207.39   109.6                 NaN
# ...

# %% [markdown]
# Merging the datasets together

# %%
Temperature['County'] = Temperature['County'].str.strip()
Temperature['County'] = Temperature['County'].str.strip()
merged_df = pd.merge(texasAQI_25, Temperature, on = 'County', how = 'inner')
print(merged_df.shape)
print(merged_df.columns)
merged_df.head()
# Out:
# (0, 24)
# Index(['State_x', 'County', 'Year', 'Days with AQI', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10', 'ID', 'State_y', 'Value',
#        'Anomaly (1901-2000 base period)', 'Rank', '1901-2000 Mean'],
#       dtype='object')
# Empty DataFrame
# Columns: [State_x, County, Year, Days with AQI, Good Days, Moderate Days, Unhealthy for Sensitive Groups Days, Unhealthy Days, Very Unhealthy Days, Hazardous Days, Max AQI, 90th Percentile AQI, Median AQI, Days CO, Days NO2, Days Ozone, Days PM2.5, Days PM10, ID, State_y, Value, Anomaly (1901-2000 base period), Rank, 1901-2000 Mean]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Keeping only relevant features (after combining all the datasets together)

# %%
keep = []
