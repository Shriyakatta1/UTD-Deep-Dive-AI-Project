# %%
import pandas as pd
import numpy as np

# %%
tree_equity = pd.read_csv('/Users/shriyakatta/UTD-Deep-Dive-AI-Project/Dataset_Files/tx_tes_cleaned_v2.csv')
tree_equity.columns
# Out:
# Index(['GEOID', 'place', 'state', 'state_abbr', 'county', 'ua_name',
#        'congressio', 'land_area', 'biome', 'tc_goal', 'treecanopy', 'tc_gap',
#        'priority_i', 'pctpocnorm', 'pctpovnorm', 'unemplnorm', 'dep_perc',
#        'depratnorm', 'health_nor', 'temp_norm', 'tes', 'tesctyscor',
#        'holc_grade', 'ej_disadva', '_bld1200', '_veg1200', '_tot1200',
#        '_bld1500', '_veg1500', '_tot1500', '_bld1800', '_veg1800', '_tot1800',
#        'rank', 'rankgrpsz'],
#       dtype='object')

# %%
remove_col = ['GEOID', 'place', 'state', 'state_abbr', 'ua_name', 'congressio', 'holc_grade', 'ej_disadva', '_bld1200', '_veg1200', '_tot1200', '_bld1500', '_veg1500', '_tot1500', '_bld1800', '_veg1800', '_tot1800']
tree_equity = tree_equity.drop(columns=remove_col)
print(tree_equity.columns)
tree_equity.head()
# Out:
# Index(['county', 'land_area', 'biome', 'tc_goal', 'treecanopy', 'tc_gap',
#        'priority_i', 'pctpocnorm', 'pctpovnorm', 'unemplnorm', 'dep_perc',
#        'depratnorm', 'health_nor', 'temp_norm', 'tes', 'tesctyscor', 'rank',
#        'rankgrpsz'],
#       dtype='object')
#             county  land_area   biome  tc_goal  treecanopy  tc_gap  \
# 0  Anderson County     1.2827  Forest      0.5      0.4475  0.0525
# 1  Anderson County     2.1241  Forest      0.5      0.5791  0.0000
# 2  Anderson County     2.5378  Forest      0.5      0.4195  0.0805
# 3  Anderson County     3.2225  Forest      0.5      0.6449  0.0000
# 4  Anderson County     2.7991  Forest      0.5      0.5738  0.0000
#
#    priority_i  pctpocnorm  pctpovnorm  unemplnorm  dep_perc  depratnorm  \
# 0    0.507741    0.303300    0.283496    0.000000  0.508665    0.694816
# 1    0.639673    0.858020    0.910096    0.656915  0.352505    0.281079
# 2    0.561506    0.734242    0.486781    0.070550  0.412879    0.414940
# 3    0.517795    0.476606    0.443385    0.000000  0.554441    0.871067
# 4    0.526463    0.534323    0.950673    0.205986  0.406532    0.399588
#
#    health_nor  temp_norm  tes  tesctyscor  rank  rankgrpsz
# 0    0.465671   0.528401   91        86.0    17         24
# 1    0.465671   0.130045  100        86.0     1         24
# 2    0.465671   0.521674   86        86.0    18         24
# 3    0.465671   0.097160  100        86.0     1         24
# 4    0.968750   0.195067  100        86.0     1         24

# %%
tree_equity.to_csv("Tree_Equity_Counties.csv")

# %%
print(tree_equity.shape)
tree_equity.isna().sum()
# Out:
# (16011, 18)
# county        0
# land_area     0
# biome         0
# tc_goal       0
# treecanopy    0
# tc_gap        0
# priority_i    0
# pctpocnorm    0
# pctpovnorm    0
# unemplnorm    0
# dep_perc      0
# depratnorm    0
# health_nor    0
# temp_norm     0
# tes           0
# tesctyscor    0
# rank          0
# rankgrpsz     0
# dtype: int64
